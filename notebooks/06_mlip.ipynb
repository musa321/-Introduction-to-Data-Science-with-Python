# %% [markdown]
# # Equivariant Machine Learned Interatomic Potentials Models
#
# Created by ***Debsundar Dey*** and ***Tejus Rohatgi***
#
# This tutorial aims to demonstrate two state-of-the-art MLIP models, **NequIP** and **MACE**.

# %% [markdown]
# ## Table of Contents
# 0. [Before Starting](#prep)
# 1. [Dataset](#dataset)
#     *   [Silicon Dataset](#silicon)
#     *   [Visualising Dataset](#visualise)
#     *   [Splitting Dataset into Training and Testing Set](#split)
# 2. [NequIP](#nequip)
#     * [Introduction](#nequip-intro)
#     * [Installing NequIP](#nequip-install)
#     * [Configuration](#nequip-config)
#     * [Training NequIP](#nequip-training)
#     * [Molecular Dynamics using NequIP](#nequip-md)
# 3. [MACE](#mace)
#     * [Introduction](#mace-intro)
#     * [Installing MACE](#mace-install)
#     * [Configuration](#mace-config)
#     * [Training MACE](#mace-training)
#     * [Molecular Dynamics using MACE](#mace-md)
#     * [MACE Foundational Models](#mace-foundational)
# 4. [Exercises](#exercises)
#     * [Evaluating NequIP and MACE](#ex-evaluate)
#     * [Play with the hyperparamters for NequIP and MACE. ](#ex-hyperparam)
#     * [Training complex datasets](#ex-botnet)
# 5. [BONUS: Visualizing `.xyz` files](#ovito)

# %% [markdown]
# ## 0. Before Starting <a name="prep"></a>

# %% [markdown]
# ### Enable GPU
#
# Training NequIP and MACE requires GPU acceleration as they are a highly complex deep neural networks. To enable GPU turn on the `T4 GPU` before running the first block.

# %%
# Install necessary packages and dependencies
# !pip install ase
# !pip install e3nn==0.4.4
# !pip install opt_einsum
# !pip install torch_ema
# !pip install prettytable
# Out:
# Collecting ase
#   Downloading ase-3.24.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.10/dist-packages (from ase) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from ase) (1.13.1)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase) (1.17.0)
# Downloading ase-3.24.0-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 52.1 MB/s eta 0:00:00
# Installing collected packages: ase
# Successfully installed ase-3.24.0
# Collecting e3nn==0.4.4
#   Downloading e3nn-0.4.4-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4) (2.5.1+cu121)
# Collecting opt-einsum-fx>=0.1.4 (from e3nn==0.4.4)
#   Downloading opt_einsum_fx-0.1.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from opt-einsum-fx>=0.1.4->e3nn==0.4.4) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from opt-einsum-fx>=0.1.4->e3nn==0.4.4) (24.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn==0.4.4) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn==0.4.4) (1.3.0)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy->e3nn==0.4.4) (1.26.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->e3nn==0.4.4) (3.0.2)
# Downloading e3nn-0.4.4-py3-none-any.whl (387 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 387.7/387.7 kB 21.6 MB/s eta 0:00:00
# Downloading opt_einsum_fx-0.1.4-py3-none-any.whl (13 kB)
# Installing collected packages: opt-einsum-fx, e3nn
# Successfully installed e3nn-0.4.4 opt-einsum-fx-0.1.4
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (3.4.0)
# Collecting torch_ema
#   Downloading torch_ema-0.3-py3-none-any.whl.metadata (415 bytes)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torch_ema) (2.5.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->torch_ema) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->torch_ema) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torch_ema) (3.0.2)
# Downloading torch_ema-0.3-py3-none-any.whl (5.5 kB)
# Installing collected packages: torch_ema
# Successfully installed torch_ema-0.3
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (3.12.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable) (0.2.13)

# %%
# Import necessary libraries (If any of the libraries doesn't install, you can use pip install the package)
import os
import random
import time
from pathlib import Path
import json
import yaml
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import pylab as pl
import torch
import ase

# %%
# Determine device is CPU or GPU
device ='cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## 1. Dataset <a name="dataset"></a>
# The dataset plays a crucial role in training and evaluating Machine Learning Interatomic Potential (MLIP) models. Its quality, diversity, and relevance significantly impact the performance and generalizability of the MLIP. The dataset provides the atomic configurations and corresponding properties (e.g., energy, forces, stress) that the MLIP aims to predict.

# %% [markdown]
# ### 1.1. Silicon Dataset <a name="silicon"></a>
# High-temperature Si data set sampled with AIMD at T = 800 K, consisting of 64 atoms per frame.

# %%
# %%capture
# download data
# !gdown --folder --id --no-cookies https://drive.google.com/drive/folders/1FEwF4i8IDHGmAIQ3RilA0jG9_lEX4Yk0?usp=sharing
# !mkdir Si_data
# !mv *.xyz ./Si_data

# %%
# !ls Si_data
# Out:
# sitraj.xyz

# %%
# Defining path to dataset for ease
dataset_dir = Path(os.getcwd()) / 'Si_data'

# %% [markdown]
# ### 1.2. Visualising Dataset <a name="visualise"></a>
#
# We will utilise the `ase` package to get more information about the datset we are looking on. Let's start with `dataset_acac/train_300K.xyz`.

# %%
from ase.io import read, write

# Load the dataset
dataset = read("Si_data/sitraj.xyz", index=":")
dataset[0]
# Out:
# Atoms(symbols='Si64', pbc=True, cell=[10.861999859992501, 10.861999859992501, 10.861999859992501], calculator=SinglePointCalculator(...))

# %%
num_configs = len(dataset)
print(f"Number of configurations in the dataset: {num_configs}")
# Out:
# Number of configurations in the dataset: 110

# %% [markdown]
# Let's utilise `ase.visualize` module to visualize the first few configurations in the datset.

# %%
from ase.visualize import view
view(dataset[0], viewer='x3d')
# Out:
# <html>
#     <head>
#         <title>ASE atomic visualization</title>
#         <link rel="stylesheet" type="text/css"             href="https://www.x3dom.org/release/x3dom.css"></link>
#         <script type="text/javascript"             src="https://www.x3dom.org/release/x3dom.js"></script>
#     </head>
#     <body>
#         <X3D width="400px"; height="300px";>
#
# <!--Inserting Generated X3D Scene-->
# <scene>
#   <viewpoint position="0 0 21.723999719985002">
#     <group/>
#   </viewpoint>
#   <transform translation="-5.430999929996251 -5.430999929996251 -5.430999929996251">
#     <group>
#       <group>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.861999859992501 0.0 0.0 10.861999859992501 10.861999859992501 0.0 0.0 10.861999859992501 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 10.861999859992501">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.861999859992501 0.0 0.0 10.861999859992501 10.861999859992501 0.0 0.0 10.861999859992501 0.0 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0 0 0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.861999859992501 0.0 0.0 10.861999859992501 0.0 10.861999859992501 0.0 0.0 10.861999859992501 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#         <transform translation="0.0 10.861999859992501 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0 0 0"/>
#             </appearance>
#             <lineset vertexCount="5">
#               <coordinate point="0 0 0 10.861999859992501 0.0 0.0 10.861999859992501 0.0 10.861999859992501 0.0 0.0 10.861999859992501 0 0 0"/>
#             </lineset>
#           </shape>
#         </transform>
#       </group>
#       <group>
#         <transform translation="0.0 0.0 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 2.71549996 2.71549996">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 2.71549996 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 0.0 2.71549996">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="4.07324995 1.35774998 4.07324995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="1.35774998 1.35774998 1.35774998">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="1.35774998 4.07324995 4.07324995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="4.07324995 4.07324995 1.35774998">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 0.0 5.43099993">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 2.71549996 8.14649989">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 2.71549996 5.43099993">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 0.0 8.14649989">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="4.07324995 1.35774998 9.50424988">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="1.35774998 1.35774998 6.78874991">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="1.35774998 4.07324995 9.50424988">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="4.07324995 4.07324995 6.78874991">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 5.43099993 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="0.0 8.14649989 2.71549996">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 8.14649989 0.0">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="2.71549996 5.43099993 2.71549996">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="4.07324995 6.78874991 4.07324995">
#           <shape>
#             <appearance>
#               <material diffuseColor="0.941 0.784 0.627"/>
#             </appearance>
#             <sphere radius="1.11"/>
#           </shape>
#         </transform>
#         <transform translation="1.35774998 6.78874991 1.35774998">
#           <shape>
#             <appearance>
#               <material diffuseColo

# %% [markdown]
# ### 1.3. Splitting Dataset into Training and Testing Set <a name="split"></a>

# %%
from sklearn.model_selection import train_test_split

# Split into train (100) and test (10)
train_set, test_set = train_test_split(dataset, test_size = 10, random_state = 123)

# Specify the train and test file path for ease
train_data = dataset_dir / "Si_train.xyz"
test_data = dataset_dir / "Si_test.xyz"

# Write them out to separate .xyz files
write(train_data, train_set)
write(test_data, test_set)

# %% [markdown]
# ## 2. NequIP <a name="nequip"></a>

# %% [markdown]
# ### 2.1. Introduction <a name="nequip-intro"></a>
#
# Welcome to the *NequIP Tutorial with Molecular Dynamics*, where we’ll train a NequIP model with AIMD data and use it for MD simulations! Think of this as a speedrun through the molecular jungle—we might skip some scenic routes (a.k.a. deep physical intuition), but we’ll get you to the finish line with a working model. So buckle up, and let’s dive into the NequIPverse.
#
# #### About NequIP
#
# NequIP employs E(3)-equivariant graph neural networks, which respect the symmetries of three-dimensional Euclidean space (rotations, translations, and reflections). This allows the model to learn both scalar (e.g., energy) and vector (e.g., forces) properties in a symmetry-aware manner.

# %% [markdown]
# ### 2.2. Installing NequIP <a name="nequip-install"></a>

# %%
# Clone NequIP
# !git clone https://github.com/mir-group/nequip.git

# Install NequIP
# !cd nequip && pip install .
# Out:
# Cloning into 'nequip'...
# remote: Enumerating objects: 14013, done.
# remote: Counting objects: 100% (4356/4356), done.
# remote: Compressing objects: 100% (561/561), done.
# remote: Total 14013 (delta 4035), reused 3906 (delta 3795), pack-reused 9657 (from 2)
# Receiving objects: 100% (14013/14013), 3.88 MiB | 13.15 MiB/s, done.
# Resolving deltas: 100% (10183/10183), done.
# Processing /content/nequip
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (1.26.4)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (3.24.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (4.67.1)
# Requirement already satisfied: e3nn<0.6.0,>=0.4.4 in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (0.4.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (6.0.2)
# Collecting torch-runstats>=0.2.0 (from nequip==0.6.1)
#   Downloading torch_runstats-0.2.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: torch-ema>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from nequip==0.6.1) (0.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (2.5.1+cu121)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (0.1.4)
# Requirement already satisfied: matplotlib>=3.3.4 in /usr/local/lib/python3.10/dist-packages (from ase->nequip==0.6.1) (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.4->ase->nequip==0.6.1) (2.8.2)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from opt-einsum-fx>=0.1.4->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.4->ase->nequip==0.6.1) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->e3nn<0.6.0,>=0.4.4->nequip==0.6.1) (3.0.2)
# Downloading torch_runstats-0.2.0-py3-none-any.whl (8.1 kB)
# Building wheels for collected packages: nequip
#   Building wheel for nequip (setup.py) ... done
#   Created wheel for nequip: filename=nequip-0.6.1-py3-none-any.whl size=175386 sha256=cc73c2f27104596e0c855e6178a3482ef2e66c5b49fa3f3717947adc4d2cf19a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fegl4x4q/wheels/11/64/44/9d30bacb0803dffa7821bb8685dbc60a0830cca339476e4e86
# Successfully built nequip
# Installing collected packages: torch-runstats, nequip
# Successfully installed nequip-0.6.1 torch-runstats-0.2.0

# %%
# !ls nequip
# Out:
# build	      configs	       docs	 LICENSE   nequip	    README.md  setup.py
# CHANGELOG.md  CONTRIBUTING.md  examples  logo.png  nequip.egg-info  setup.cfg  tests

# %% [markdown]
# ### 2.3. Configuration <a name="nequip-config"></a>

# %%
# Specify Paths
nequip_dir = Path(os.getcwd()) / 'nequip'
nequip_configs_dir = nequip_dir / 'configs'
nequip_results_dir = nequip_dir / 'results'

# Create directories if not exists
os.makedirs(nequip_configs_dir, exist_ok=True)
os.makedirs(nequip_results_dir, exist_ok=True)

# %% [markdown]
# #### 2.3.1. Hyperparameters in Training NequIP <a name="nequip-hypparam"></a>
# For configuring the hyperparameters, we can specify a YAML file. The following is an example:

# %%
# Specifying parameters for training a NequIP model

parameters_nequip = {

    # Specify model name and save directories
    "root": str(nequip_results_dir),
    "run_name": "si",

    # Dataset
    "dataset": "ase",
    "dataset_file_name": str(train_data),

    "key_mapping": {
        "z": "atomic_numbers",
        "E": "total_energy",
        "F": "forces",
        "R": "pos",
    },
    "chemical_symbols": ["Si"],


    # Hyperparameters
    "num_features": 64, # Number of channels determining the size of the model
    "r_max": 4.0,  # Maximum interaction radius
    "l_max": 1, # Symmetry of messages
    "parity": "true", # whether to include features with odd mirror parity
    "num_layers": 4,  # Number of message-passing layers in the model
    # radial network
    "num_basis": 8, # number of basis functions used in the radial basis, 8 usually works best
    "invariant_layers": 2, # number of radial layers, usually 1-3 works best, smaller is faster
    "invariant_neurons": 64,  # number of hidden neurons in radial function, smaller is faster

    # Optimization
    "n_train": "80%", # Fraction of the training set to use as training
    "n_val": "20%", # Fraction of the training set to use as validation
    "batch_size": 10, # Batch size for training
    "max_epochs": 50, # Maximum number of epochs
    "default_dtype": "float64", # Precision for calculations
    "model_dtype": "float32",
    "wandb": False, # Logging
    "device": device, # Device to use ("cuda" for GPU)
    "seed": 123,
    "dataset_seed": 123,

    # Output Metrics
    "metrics_components": [
        ["forces", "mae"],
        ["forces", "rmse"],
        ["total_energy", "mae"],
        ["total_energy", "rmse"]
    ],
}


# Save parameters to a YAML file
input_nequip = nequip_configs_dir / "input.yaml"

with open(input_nequip, "w") as file:
    yaml.dump(parameters_nequip, file, default_flow_style=False)

print(f"Parameters have been saved to {input_nequip}")
# Out:
# Parameters have been saved to /content/nequip/configs/input.yaml

# %% [markdown]
# ### 2.4. Training NequIP <a name="nequip-train"></a>
#
# To train a NequIP model, you can use the `nequip-train` file.

# %%
# %%time
# !nequip-train nequip/configs/input.yaml
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# Torch device: cuda
# Processing dataset...
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# /usr/local/lib/python3.10/dist-packages/nequip/utils/_global_options.py:95: UserWarning: Do NOT manually set PYTORCH_JIT_USE_NNC_NOT_NVFUSER=0 unless you know exactly what you're doing!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/utils/_global_options.py:95: UserWarning: Do NOT manually set PYTORCH_JIT_USE_NNC_NOT_NVFUSER=0 unless you know exactly what you're doing!
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/data/_dataset/_ase_dataset.py:231: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   datas = [torch.load(d) for d in datas]
# Loaded data: Batch(atomic_numbers=[6400, 1], batch=[6400], cell=[100, 3, 3], edge_cell_shift=[89350, 3], edge_index=[2, 89350], forces=[6400, 3], free_energy=[100], pbc=[100, 3], pos=[6400, 3], ptr=[101], stress=[100, 3, 3], total_energy=[100, 1])
#     processed data size: ~3.82 MB
# Cached processed data to disk
# Done!
# Successfully loaded the data set of type ASEDataset(100)...
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# Replace string dataset_per_atom_total_energy_mean to -129.95915023989306
# Atomic outputs are scaled by: [Si: None], shifted by [Si: -129.959150].
# Replace string dataset_forces_rms to 0.9112465747539226
# Initially outputs are globally scaled by: 0.9112465747539226, total_energy are globally shifted by None.
# Successfully built the network...
# Number of weights: 389224
# Number of trainable weights: 389224
# ! Starting training ...
#
# validation
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#       0     4     1.09e+04     1.09e+04         1.09         1.35         94.9         94.9
#
#
#   Initialization     #    Epoch      wal       LR       loss_e         loss        f_mae       f_rmse        e_mae       e_rmse
# ! Initial Validation          0    4.845     0.01     1.07e+04     1.07e+04         1.12          1.4         94.4         94.4
# Wall time: 4.844974181999987
# ! Best model        0 10729.304
#
# training
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#       1     8      1.2e+03      1.2e+03        0.694        0.911         31.4         31.5
#
# validation
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#       1     4     1.14e+03     1.14e+03        0.766        0.952         30.8         30.8
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        f_mae       f_rmse        e_mae       e_rmse
# ! Train               1    6.521     0.01     3.09e+03     3.09e+03        0.751        0.962         42.5         50.7
# ! Validation          1    6.521     0.01     1.11e+03     1.11e+03        0.788        0.984         30.4         30.4
# Wall time: 6.521495676000086
# ! Best model        1 1109.733
#
# training
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#       2     8          242          242         0.71        0.906         14.2         14.2
#
# validation
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#      50     8          0.9          0.9        0.432        0.559        0.784        0.864
#
# validation
# # Epoch batch         loss       loss_e        f_mae       f_rmse        e_mae       e_rmse
#      50     4       0.0378       0.0378        0.427         0.55        0.157        0.177
#
#
#   Train      #    Epoch      wal       LR       loss_e         loss        f_mae       f_rmse        e_mae       e_rmse
# ! Train              50   54.235     0.01         1.01         1.01        0.449        0.583        0.618        0.915
# ! Validation         50   54.235     0.01        0.213        0.213        0.442        0.575        0.358        0.421
# Wall time: 54.234912713000085
# ! Stop training: max epochs
# Wall time: 54.256996632000096
# Cumulative wall time: 54.256996632000096
# CPU times: user 601 ms, sys: 73.6 ms, total: 675 ms
# Wall time: 1min 12s

# %% [markdown]
# **Extra:** Try running the model with different hyperparameters. For extensive information on the hyperparameters, check out the `nequip/configs/full.yaml` file.

# %%
# Check the output files
nequip_train_dir = nequip_results_dir / parameters_nequip["run_name"]
for file in nequip_train_dir.rglob("*"):
    print(file)
# Out:
# /content/nequip/results/si/metrics_batch_val.csv
# /content/nequip/results/si/config.yaml
# /content/nequip/results/si/last_model.pth
# /content/nequip/results/si/metrics_batch_train.csv
# /content/nequip/results/si/best_model.pth
# /content/nequip/results/si/metrics_initialization.csv
# /content/nequip/results/si/trainer.pth
# /content/nequip/results/si/log
# /content/nequip/results/si/metrics_epoch.csv

# %% [markdown]
# Check the file saved as `metric_epoch.csv` for information of about training.

# %%
nequip_train_csv = nequip_train_dir / "metrics_epoch.csv"

# Load the CSV file
df = pd.read_csv(nequip_train_csv)

df.head()
# Out:
#    epoch    wall    LR  training_loss_e  training_loss  training_f_mae  \
# 0      1   6.521  0.01         3093.800       3093.800           0.751
# 1      2   7.445  0.01          339.230        339.230           0.722
# 2      3   8.403  0.01          111.450        111.450           0.702
# 3      4   9.465  0.01           38.043         38.043           0.704
# 4      5  10.598  0.01           14.334         14.334           0.708
#
#    training_f_rmse  training_e_mae  training_e_rmse  validation_loss_e  \
# 0            0.962           42.50            50.70           1109.700
# 1            0.910           14.00            16.80            251.220
# 2            0.885            8.71             9.62             74.449
# 3            0.886            5.08             5.62             25.609
# 4            0.892            3.07             3.45             11.235
#
#    validation_loss  validation_f_mae  validation_f_rmse  validation_e_mae  \
# 0         1109.700             0.788              0.984             30.40
# 1          251.220             0.708              0.885             14.40
# 2           74.449             0.729              0.912              7.85
# 3           25.609             0.722              0.902              4.59
# 4           11.235             0.729              0.911              3.02
#
#    validation_e_rmse
# 0              30.40
# 1              14.40
# 2               7.86
# 3               4.61
# 4               3.05

# %%
# Columns to plot
metrics = [
    # 'training_loss_e',
    'training_loss',
    #  'training_f_mae',
    #  'training_f_rmse',
    #  'training_e_mae',
    #  'training_e_rmse',
    #  'validation_loss_e',
    'validation_loss',
    #  'validation_f_mae',
    #  'validation_f_rmse',
    #  'validation_e_mae',
    #  'validation_e_rmse',
    ]

# Plot each metric against the epoch
plt.figure(figsize=(10, 6))
for metric in df.columns:
    if metric in metrics:
        plt.plot(df['epoch'], df[metric], label=metric)

# Add labels, title, and legend
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.title('NequIP Training')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ### 2.5. Molecular Dynamics using NequIP <a name="nequip-md"></a>

# %% [markdown]
# Molecular dynamics (MD) is a computer simulation technique used to model and analyze the physical movements of atoms and molecules over time. By applying the principles of classical mechanics, specifically Newton's equations of motion, MD calculates the trajectories of particles based on the forces acting between them. These forces are typically derived from potential energy functions that describe interactions such as bonding, electrostatics, and van der Waals forces. The MLIPs are the potential energy functions we are using here.

# %% [markdown]
# #### 2.5.1. ASE Molecular Dynamics <a name="nequip-md-ase"></a>
#
# We will be using ASE (Atomic Simulation Environment) for performing a simple MD simulations using the module [`ase.md`](https://wiki.fysik.dtu.dk/ase/ase/md.html).
#
# The function `simpleMD()` is based on this [tutorial](https://colab.research.google.com/drive/1ZrTuTvavXiCxTFyjBV4GqlARxgFwYAtX).

# %%
from ase import units
from ase.md.langevin import Langevin
from ase.md.velocitydistribution import Stationary, ZeroRotation, MaxwellBoltzmannDistribution
from ase.calculators.calculator import Calculator
from IPython import display

def simpleMD(
    init_conf: ase.Atoms,
    temp: float,
    calc: Calculator,
    fname: str,
    s: int,
    T: int,
    seed = 123,
    init_temp = 300,
    friction = 0.1,
    ) -> None:
    """
    Perform a simple molecular dynamics (MD) simulation using the Langevin thermostat.

    Parameters:
    -----------
    init_conf : Initial atomic configuration to start the simulation.
    temp :  Target temperature of the system in Kelvin.
    calc :  Calculator to compute forces and energies for the simulation.
    fname :  Filename to store the trajectory (.xyz format).
    s :  Interval (in steps) to save frames and update the plot.
    T :  Total number of MD steps to run.
    seed: To ensure reproducibiity
    init_temp: Initialization temperature
    friction: Damping factor in Langevin

    Returns: None
    """

    # Assign the calculator for force and energy calculations
    init_conf.set_calculator(calc)

    # Initialize the temperature of the system
    random.seed(123)  # Seed for reproducibility
    MaxwellBoltzmannDistribution(init_conf, temperature_K=init_temp)  # Initial temp 300 K
    Stationary(init_conf)  # Remove net momentum
    ZeroRotation(init_conf)  # Remove angular momentum

    # Set up the Langevin thermostat
    dyn = Langevin(init_conf, 1.0 * units.fs, temperature_K=temp, friction=friction)

    # Required for inline plotting in Jupyter Notebook
    # %matplotlib inline

    # Initialize lists to store time, temperature, and energy
    time_fs = []
    temperature = []
    energies = []

    # Remove any existing trajectory file with the same name
    os.system("rm -rfv " + fname)

    # Create a plot with two subplots
    fig, ax = pl.subplots(2, 1, figsize=(10, 6), sharex="all", gridspec_kw={"hspace": 0, "wspace": 0})

    def write_frame():
        """
        Function to save a frame of the trajectory and update the live plot.
        """
        dyn.atoms.write(fname, append=True)  # Append current configuration to file
        time_fs.append(dyn.get_time() / units.fs)  # Store current simulation time
        temperature.append(dyn.atoms.get_temperature())  # Store current temperature
        energies.append(dyn.atoms.get_potential_energy() / len(dyn.atoms))  # Potential energy per atom

        # Update the plot
        ax[0].plot(np.array(time_fs), np.array(energies), color="b")
        ax[0].set_ylabel("E (eV/atom)")

        ax[1].plot(np.array(time_fs), temperature, color="r")
        ax[1].set_ylabel("T (K)")
        ax[1].set_xlabel("Time (fs)")
        ax[1].axhline(y=temp, linestyle = '--', c = "black")

        # Clear the previous plot and display the updated one
        display.clear_output(wait=True)
        display.display(pl.gcf())
        time.sleep(0.01)  # Pause for a short time to make the updates visible

    # Attach the write_frame function to be called every `s` steps
    dyn.attach(write_frame, interval=s)

    # Run the MD simulation and time its execution
    t0 = time.time()
    dyn.run(T)
    t1 = time.time()

    print("MD finished in {0:.2f} minutes!".format((t1 - t0) / 60))

# %% [markdown]
# We use Langevin thermostat using [`ase.md.langevin.Langevin`](https://wiki.fysik.dtu.dk/ase/ase/md.html#module-ase.md.langevin).
#
# [Langevin dynamics](https://en.wikipedia.org/wiki/Langevin_dynamics) is a computational simulation method used to model the behavior of particles in a system by incorporating both deterministic and stochastic (random) forces. It extends classical molecular dynamics (MD) by introducing additional terms to account for the interaction of particles with their surrounding environment, typically represented as a heat bath. This approach is particularly useful for simulating systems at a constant temperature and for capturing the effects of thermal fluctuations and friction without explicitly modeling every component of the environment.
#
# \begin{equation}
# M \ddot{\mathbf{X}} = -\nabla U(\mathbf{X}) - \gamma M \dot{\mathbf{X}} + \sqrt{2 M \gamma k_{\mathrm{B}} T} \, \mathbf{R}(t),
# \end{equation}

# %% [markdown]
# #### 2.5.2. Deploying NequIP Model <a name="nequip-md-deploy"></a>
# The `nequip-deploy` command is used to deploy the result of a training session into a model that can be stored and used for inference. It compiles a NequIP model trained in Python to TorchScript. The result is an optimized model file that has no dependency on the nequip Python library, or even on Python itself

# %%
# !nequip-deploy build \
--train-dir nequip/results/si/  nequip/results/si/deployed_model.pth
# Out:
# /usr/local/lib/python3.10/dist-packages/nequip/__init__.py:20: UserWarning: !! PyTorch version 2.5.1 found. Upstream issues in PyTorch versions 1.13.* and 2.* have been seen to cause unusual performance degredations on some CUDA systems that become worse over time; see https://github.com/mir-group/nequip/discussions/311. The best tested PyTorch version to use with CUDA devices is 1.11; while using other versions if you observe this problem, an unexpected lack of this problem, or other strange behavior, please post in the linked GitHub issue.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# INFO:root:Loading best_model.pth from training session...
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/nequip/scripts/deploy.py:327: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(
# INFO:root:Compiled & optimized model.

# %% [markdown]
# #### 2.5.3. NequIP Calculator <a name="nequip-md-calc"></a>
# NequIP models can run molecular dynamics or geometry optimisation through the ASE calculator.

# %%
init_conf = read(test_data, index=0)
init_conf
# Out:
# Atoms(symbols='Si64', pbc=True, cell=[10.861999859992501, 10.861999859992501, 10.861999859992501], calculator=SinglePointCalculator(...))

# %%
from nequip.ase import NequIPCalculator

# Specify the path to the pre-trained MACE model
nequip_model = nequip_train_dir / "deployed_model.pth"

# Initialize the NequIP calculator with the specified model
nequip_calc = NequIPCalculator.from_deployed_model(nequip_model)

# Call the simpleMD function to perform a molecular dynamics simulation
simpleMD(init_conf, temp=800, calc=nequip_calc, fname= 'nequip/results/nequip_md_si_800K.xyz', s=10, T=500)
# Out:
# MD finished in 1.88 minutes!

# %% [markdown]
# ## 3. MACE <a name="mace"></a>

# %% [markdown]
# ### 3.1. Introduction <a name="mace-intro"></a>
# #### About MACE
#
# [MACE](https://proceedings.neurips.cc/paper_files/paper/2022/hash/4a36c3c51af11ed9f34615b81edb5bbc-Abstract-Conference.html) is a machine learning interatomic potential (MLIP) framework that leverages **message-passing neural networks (MPNNs)** with equivariant representations to capture **complex many-body interactions** in atomic systems.
#
# Inspired from [ACE](https://doi.org/10.1103/PhysRevB.99.014104)-framework, MACE implements a many-body order basis and combines it with message passing framework similar to NequIP to resulting in a fast and highly parallelizable model, reaching or exceeding state-of-the-art accuracy, reducing the number of message passing iterations to just two. For a deeper dive refer to [this paper](https://arxiv.org/abs/2205.06643).
#
# #### Objective
# This tutorial aims to give a brief introduction to using MACE for training on dataset and implementing a simple Molecular Dynamics code.

# %% [markdown]
# ### 3.2. Installing MACE <a name="mace-install"></a>

# %%
# Clone MACE
# !git clone --depth 1 https://github.com/ACEsuit/mace.git

# Install MACE
# !cd mace && pip install .
# Out:
# Cloning into 'mace'...
# remote: Enumerating objects: 112, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (106/106), done.
# remote: Total 112 (delta 3), reused 26 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (112/112), 115.59 MiB | 15.91 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# Processing /content/mace
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=1.12 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (2.5.1+cu121)
# Requirement already satisfied: e3nn==0.4.4 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (0.4.4)
# Requirement already satisfied: numpy<2.0 in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (1.26.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.4.0)
# Requirement already satisfied: ase in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.24.0)
# Requirement already satisfied: torch-ema in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (0.3)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.12.0)
# Collecting matscipy (from mace-torch==0.3.10)
#   Downloading matscipy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (37 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.12.1)
# Collecting torchmetrics (from mace-torch==0.3.10)
#   Downloading torchmetrics-1.6.1-py3-none-any.whl.metadata (21 kB)
# Collecting python-hostlist (from mace-torch==0.3.10)
#   Downloading python-hostlist-2.2.1.tar.gz (37 kB)
#   Preparing metadata (setup.py) ... done
# Collecting configargparse (from mace-torch==0.3.10)
#   Downloading ConfigArgParse-1.7-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: GitPython in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.1.43)
# Requirement already satisfied: pyYAML in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (4.67.1)
# Collecting cuequivariance-torch (from mace-torch==0.3.10)
#   Downloading cuequivariance_torch-0.1.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (3.8.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from mace-torch==0.3.10) (2.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.10) (1.13.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.10) (1.13.1)
# Requirement already satisfied: opt-einsum-fx>=0.1.4 in /usr/local/lib/python3.10/dist-packages (from e3nn==0.4.4->mace-torch==0.3.10) (0.1.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.10) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.10) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.10) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.10) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.12->mace-torch==0.3.10) (2024.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->e3nn==0.4.4->mace-torch==0.3.10) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->mace-torch==0.3.10) (2.8.2)
# Collecting cuequivariance (from cuequivariance-torch->mace-torch==0.3.10)
#   Downloading cuequivariance-0.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from GitPython->mace-torch==0.3.10) (4.0.11)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch==0.3.10) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->mace-torch==0.3.10) (2024.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->mace-torch==0.3.10) (0.2.13)
# Collecting lightning-utilities>=0.8.0 (from torchmetrics->mace-torch==0.3.10)
#   Downloading lightning_utilities-0.11.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->GitPython->mace-torch==0.3.10) (5.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->torchmetrics->mace-torch==0.3.10) (75.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->mace-torch==0.3.10) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.12->mace-torch==0.3.10) (3.0.2)
# Downloading ConfigArgParse-1.7-py3-none-any.whl (25 kB)
# Downloading cuequivariance_torch-0.1.0-py3-none-any.whl (39 kB)
# Downloading matscipy-1.1.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (448 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 448.8/448.8 kB 31.7 MB/s eta 0:00:00
# Downloading torchmetrics-1.6.1-py3-none-any.whl (927 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 58.3 MB/s eta 0:00:00
# Downloading lightning_utilities-0.11.9-py3-none-any.whl (28 kB)
# Downloading cuequivariance-0.1.0-py3-none-any.whl (102 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.5/102.5 kB 9.9 MB/s eta 0:00:00
# Building wheels for collected packages: mace-torch, python-hostlist
#   Building wheel for mace-torch (pyproject.toml) ... done
#   Created wheel for mace-torch: filename=mace_torch-0.3.10-py3-none-any.whl size=152330 sha256=ca0109d38998ad1298633646ecda0b24830bd01cc454be7ce696eb16cec51aaa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-r4_ipznq/wheels/df/5f/32/ef59561725170a81c728fd01c75e56a9ee83bad6da485fc6a5
#   Building wheel for python-hostlist (setup.py) ... done
#   Created wheel for python-hostlist: filename=python_hostlist-2.2.1-py3-none-any.whl size=39603 sha256=4f26cbbc905144de58ca6114f52ef8fab0ff58c0470668f15bdf45ec5d99e5f5
#   Stored in directory: /root/.cache/pip/wheels/7a/a0/4e/057d4c6df390bb2f8c7c171df7bb39c124549a6b66cbe3480f
# Successfully built mace-torch python-hostlist
# Installing collected packages: python-hostlist, lightning-utilities, configargparse, cuequivariance, torchmetrics, cuequivariance-torch, matscipy, mace-torch
# Successfully installed configargparse-1.7 cuequivariance-0.1.0 cuequivariance-torch-0.1.0 lightning-utilities-0.11.9 mace-torch-0.3.10 matscipy-1.1.1 python-hostlist-2.2.1 torchmetrics-1.6.1

# %%
# View MACE directory
# !ls mace
# Out:
# build	    mace		 MANIFEST.in	 README.md  setup.cfg
# LICENSE.md  mace_torch.egg-info  pyproject.toml  scripts    tests

# %% [markdown]
# ### 3.3. Configuration <a name="mace-config"></a>

# %%
# Specify paths
mace_dir = Path(os.getcwd()) / 'mace'
mace_configs_dir = mace_dir / 'configs'
mace_results_dir = mace_dir / 'results'

# Create directories if not exists
os.makedirs(mace_configs_dir, exist_ok=True)
os.makedirs(mace_results_dir, exist_ok=True)

# %% [markdown]
# #### 3.3.1 Hyperparameters in Training MACE
#
# For configuring the hyperparameters, we can specify a YAML file. The following is an example:

# %%
# Specifying parameters for training a MACE model

parameters_mace = {

    # Specify model name and save directories
    "name": "si",  # Name of the model being trained
    "model_dir": str(mace_results_dir),
    "log_dir": str(mace_results_dir),
    "checkpoints_dir": str(mace_results_dir),
    "results_dir": str(mace_results_dir),

    # Train file specifications
    "train_file": str(train_data),  # Path to training data
    "forces_key": "forces",  # Key for forces in the dataset
    "energy_key": "energy",  # Key for energy in the dataset

    # From isolated_atoms.xyz get the reference energies for isolated atoms.
    "E0s": "average",

    # Hyperparameters
    "model": "MACE",  # Type of model to train (https://mace-docs.readthedocs.io/en/latest/guide/training.html#model)
    "num_channels": 64, # Number of channels determining the size of the model
    "r_max": 4.0,  # Maximum interaction radius
    "max_L": 1, # Symmetry of messages

    "num_interactions": 2,  # Number of message-passing layers in the model (recommended to keep default)
    "correlation": 3, # The order of the many-body expansion, correlation = body order - 1 (recommended to keep default)
    "max_ell": 3, # The angular resolution describes how well the model can describe angles (recommended to keep default)

    # Optimization
    "valid_fraction": 0.05, # Fraction of the training set to use as validation
    "batch_size": 10, # Batch size for training
    "max_num_epochs": 50, # Maximum number of epochs
    "default_dtype": "float32", # Precision for calculations
    "device": device, # Device to use ("cuda" for GPU)
    "seed": 123,
}

# Save parameters to a YAML file
input_mace = mace_configs_dir / "input.yaml"

with open(input_mace, "w") as file:
    yaml.dump(parameters_mace, file, default_flow_style=False)

print(f"Parameters have been saved to {input_mace}")
# Out:
# Parameters have been saved to /content/mace/configs/input.yaml

# %% [markdown]
# ### 3.4. Training MACE <a name="mace-train"></a>

# %% [markdown]
# To train a MACE model, you can use the `run_train.py` script.

# %%
# %%time
# !python3 ./mace/scripts/run_train.py --config="mace/configs/input.yaml"
# Out:
# /usr/local/lib/python3.10/dist-packages/e3nn/o3/_wigner.py:10: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# 2025-01-08 06:36:14.502 INFO: ===========VERIFYING SETTINGS===========
# 2025-01-08 06:36:14.502 INFO: MACE version: 0.3.10
# 2025-01-08 06:36:14.528 INFO: CUDA version: 12.1, CUDA device: 0
# 2025-01-08 06:36:14.686 INFO: ===========LOADING INPUT DATA===========
# 2025-01-08 06:36:14.686 INFO: Using heads: ['default']
# 2025-01-08 06:36:14.686 INFO: =============    Processing head default     ===========
# 2025-01-08 06:36:14.780 WARNING: Since ASE version 3.23.0b1, using energy_key 'energy' is no longer safe when communicating between MACE and ASE. We recommend using a different key, rewriting 'energy' to 'REF_energy'. You need to use --energy_key='REF_energy' to specify the chosen key name.
# 2025-01-08 06:36:14.796 WARNING: Since ASE version 3.23.0b1, using forces_key 'forces' is no longer safe when communicating between MACE and ASE. We recommend using a different key, rewriting 'forces' to 'REF_forces'. You need to use --forces_key='REF_forces' to specify the chosen key name.
# 2025-01-08 06:36:14.816 INFO: Training set [100 configs, 100 energy, 19200 forces] loaded from '/content/Si_data/Si_train.xyz'
# 2025-01-08 06:36:14.817 INFO: Using random 5% of training set for validation with following indices: [22, 91, 35, 25, 77]
# 2025-01-08 06:36:14.817 INFO: Validaton set contains 5 configurations [5 energy, 960 forces]
# 2025-01-08 06:36:14.817 INFO: Total number of configurations: train=95, valid=5, tests=[],
# 2025-01-08 06:36:14.818 WARNING: Validation batch size (10) is larger than the number of validation data (5)
# 2025-01-08 06:36:14.819 INFO: Atomic Numbers used: [14]
# 2025-01-08 06:36:14.819 INFO: Isolated Atomic Energies (E0s) not in training file, using command line argument
# 2025-01-08 06:36:14.819 INFO: Computing average Atomic Energies using least squares regression
# 2025-01-08 06:36:14.820 INFO: Atomic Energies used (z: eV) for head default: {14: -129.95866796583886}
# 2025-01-08 06:36:14.977 INFO: Computing average number of neighbors
# 2025-01-08 06:36:15.141 INFO: Average number of neighbors: 13.948264122009277
# 2025-01-08 06:36:15.141 INFO: During training the following quantities will be reported: energy, forces
# 2025-01-08 06:36:15.141 INFO: ===========MODEL DETAILS===========
# 2025-01-08 06:36:15.174 INFO: Building model
# 2025-01-08 06:36:15.174 INFO: Message passing with 64 channels and max_L=1 (64x0e+64x1o)
# 2025-01-08 06:36:15.175 INFO: 2 layers, each with correlation order: 3 (body order: 4) and spherical harmonics up to: l=3
# 2025-01-08 06:36:15.175 INFO: 8 radial and 5 basis functions
# 2025-01-08 06:36:15.175 INFO: Radial cutoff: 4.0 A (total receptive field for each atom: 8.0 A)
# 2025-01-08 06:36:15.175 INFO: Distance transform for radial basis functions: None
# 2025-01-08 06:36:15.175 INFO: Hidden irreps: 64x0e+64x1o
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torch/jit/_check.py:178: UserWarning: The TorchScript type system doesn't support instance-level annotations on empty non-base types in `__init__`. Instead, either 1) use a type annotation in the class body, or 2) wrap the type in `torch.jit.Attribute`.
#   warnings.warn(
# 2025-01-08 06:36:17.108 INFO: Total number of parameters: 185616
# 2025-01-08 06:36:17.108 INFO:
# 2025-01-08 06:36:17.108 INFO: ===========OPTIMIZER INFORMATION===========
# 2025-01-08 06:36:17.108 INFO: Using ADAM as parameter optimizer
# 2025-01-08 06:36:17.109 INFO: Batch size: 10
# 2025-01-08 06:36:17.109 INFO: Number of gradient updates: 475
# 2025-01-08 06:36:17.109 INFO: Learning rate: 0.01, weight decay: 5e-07
# 2025-01-08 06:36:17.109 INFO: WeightedEnergyForcesLoss(energy_weight=1.000, forces_weight=100.000)
# 2025-01-08 06:36:17.109 INFO: Using gradient clipping with tolerance=10.000
# 2025-01-08 06:36:17.109 INFO:
# 2025-01-08 06:36:17.110 INFO: ===========TRAINING===========
# 2025-01-08 06:36:17.110 INFO: Started training, reporting errors on validation set
# 2025-01-08 06:36:17.110 INFO: Loss metrics on validation set
# 2025-01-08 06:36:18.225 INFO: Initial: head: default, loss=17.67835426, RMSE_E_per_atom=   25.14 meV, RMSE_F=  940.17 meV / A
# 2025-01-08 06:36:33.372 INFO: Epoch 0: head: default, loss=6.78979254, RMSE_E_per_atom= 1047.89 meV, RMSE_F=  573.16 meV / A
# 2025-01-08 06:36:36.311 INFO: Epoch 1: head: default, loss=1.21400440, RMSE_E_per_atom=  721.59 meV, RMSE_F=  235.57 meV / A
# 2025-01-08 06:36:37.967 INFO: Epoch 2: head: default, loss=0.82006776, RMSE_E_per_atom=  829.92 meV, RMSE_F=  184.70 meV / A
# 2025-01-08 06:36:39.602 INFO: Epoch 3: head: default, loss=0.48053154, RMSE_E_per_atom=  913.90 meV, RMSE_F=  125.20 meV / A
# 2025-01-08 06:36:41.115 INFO: Epoch 4: head: default, loss=0.37721664, RMSE_E_per_atom=  742.33 meV, RMSE_F=  115.54 meV / A
# 2025-01-08 06:36:42.626 INFO: Epoch 5: head: default, loss=0.28902254, RMSE_E_per_atom=  579.03 meV, RMSE_F=  105.35 meV / A
# 2025-01-08 06:36:44.145 INFO: Epoch 6: head: default, loss=0.24573930, RMSE_E_per_atom=  391.33 meV, RMSE_F=  103.71 meV / A
# 2025-01-08 06:36:45.667 INFO: Epoch 7: head: default, loss=0.21851906, RMSE_E_per_atom=  235.53 meV, RMSE_F=  101.84 meV / A
# 2025-01-08 06:36:47.210 INFO: Epoch 8: head: default, loss=0.19206181, RMSE_E_per_atom=  124.33 meV, RMSE_F=   97.20 meV / A
# 2025-01-08 06:36:48.724 INFO: Epoch 9: head: default, loss=0.16350962, RMSE_E_per_atom=   42.28 meV, RMSE_F=   90.32 meV / A
# 2025-01-08 06:36:50.306 INFO: Epoch 10: head: default, loss=0.14130729, RMSE_E_per_atom=    7.52 meV, RMSE_F=   84.05 meV / A
# 2025-01-08 06:36:52.015 INFO: Epoch 11: head: default, loss=0.11791738, RMSE_E_per_atom=   12.73 meV, RMSE_F=   76.77 meV / A
# 2025-01-08 06:36:53.651 INFO: Epoch 12: head: default, loss=0.09147747, RMSE_E_per_atom=   51.46 meV, RMSE_F=   67.43 meV / A
# 2025-01-08 06:36:55.386 INFO: Epoch 13: head: default, loss=0.07739103, RMSE_E_per_atom=   11.08 meV, RMSE_F=   62.20 meV / A
# 2025-01-08 06:36:57.004 INFO: Epoch 14: head: default, loss=0.07497687, RMSE_E_per_atom=   12.05 meV, RMSE_F=   61.22 meV / A
# 2025-01-08 06:36:58.523 INFO: Epoch 15: head: default, loss=0.06644268, RMSE_E_per_atom=   10.84 meV, RMSE_F=   57.63 meV / A
# 2025-01-08 06:37:00.035 INFO: Epoch 16: head: default, loss=0.06111205, RMSE_E_per_atom=    1.77 meV, RMSE_F=   55.28 meV / A
# 2025-01-08 06:37:01.546 INFO: Epoch 17: head: default, loss=0.05877437, RMSE_E_per_atom=   28.56 meV, RMSE_F=   54.13 meV / A
# 2025-01-08 06:37:03.404 INFO: Epoch 18: head: default, loss=0.05411937, RMSE_E_per_atom=    4.12 meV, RMSE_F=   52.02 meV / A
# 2025-01-08 06:37:05.225 INFO: Epoch 19: head: default, loss=0.05810582, RMSE_E_per_atom=    3.22 meV, RMSE_F=   53.90 meV / A
# 2025-01-08 06:37:06.847 INFO: Epoch 20: head: default, loss=0.07643950, RMSE_E_per_atom=   10.36 meV, RMSE_F=   61.81 meV / A
# 2025-01-08 06:37:08.447 INFO: Epoch 21: head: default, loss=0.04716614, RMSE_E_per_atom=    7.54 meV, RMSE_F=   48.56 meV / A
# 2025-01-08 06:37:09.976 INFO: Epoch 22: head: default, loss=0.04440219, RMSE_E_per_atom=    3.13 meV, RMSE_F=   47.12 meV / A
# 2025-01-08 06:37:11.501 INFO: Epoch 23: head: default, loss=0.05179835, RMSE_E_per_atom=    7.29 meV, RMSE_F=   50.89 meV / A
# 2025-01-08 06:37:13.000 INFO: Epoch 24: head: default, loss=0.04115733, RMSE_E_per_atom=    7.33 meV, RMSE_F=   45.36 meV / A
# 2025-01-08 06:37:14.522 INFO: Epoch 25: head: default, loss=0.04252082, RMSE_E_per_atom=   14.84 meV, RMSE_F=   46.09 meV / A
# 2025-01-08 06:37:16.018 INFO: Epoch 26: head: default, loss=0.04223559, RMSE_E_per_atom=    2.77 meV, RMSE_F=   45.95 meV / A
# 2025-01-08 06:37:17.518 INFO: Epoch 27: head: default, loss=0.04074950, RMSE_E_per_atom=    3.75 meV, RMSE_F=   45.14 meV / A
# 2025-01-08 06:37:19.106 INFO: Epoch 28: head: default, loss=0.04098115, RMSE_E_per_atom=    9.57 meV, RMSE_F=   45.26 meV / A
# 2025-01-08 06:37:20.729 INFO: Epoch 29: head: default, loss=0.03846943, RMSE_E_per_atom=    1.98 meV, RMSE_F=   43.86 meV / A
# 2025-01-08 06:37:22.328 INFO: Epoch 30: head: default, loss=0.03709809, RMSE_E_per_atom=    3.56 meV, RMSE_F=   43.07 meV / A
# 2025-01-08 06:37:23.853 INFO: Epoch 31: head: default, loss=0.03660786, RMSE_E_per_atom=    8.38 meV, RMSE_F=   42.77 meV / A
# 2025-01-08 06:37:25.383 INFO: Epoch 32: head: default, loss=0.03383929, RMSE_E_per_atom=   19.86 meV, RMSE_F=   41.09 meV / A
# 2025-01-08 06:37:26.907 INFO: Epoch 33: head: default, loss=0.03304159, RMSE_E_per_atom=    1.21 meV, RMSE_F=   40.65 meV / A
# 2025-01-08 06:37:28.430 INFO: Epoch 34: head: default, loss=0.03154485, RMSE_E_per_atom=   11.62 meV, RMSE_F=   39.70 meV / A
# 2025-01-08 06:37:29.956 INFO: Epoch 35: head: default, loss=0.03506692, RMSE_E_per_atom=   13.44 meV, RMSE_F=   41.85 meV / A
# 2025-01-08 06:37:31.467 INFO: Epoch 36: head: default, loss=0.02840396, RMSE_E_per_atom=    5.68 meV, RMSE_F=   37.68 meV / A
# 2025-01-08 06:37:33.090 INFO: Epoch 37: head: default, loss=0.02789737, RMSE_E_per_atom=    2.99 meV, RMSE_F=   37.35 meV / A
# 2025-01-08 06:37:34.773 INFO: Epoch 38: head: default, loss=0.03487375, RMSE_E_per_atom=    8.70 meV, RMSE_F=   41.75 meV / A
# 2025-01-08 06:37:36.293 INFO: Epoch 39: head: default, loss=0.03638945, RMSE_E_per_atom=   14.98 meV, RMSE_F=   42.63 meV / A
# 2025-01-08 06:37:37.802 INFO: Epoch 40: head: default, loss=0.02802997, RMSE_E_per_atom=   14.59 meV, RMSE_F=   37.41 meV / A
# 2025-01-08 06:37:39.304 INFO: Epoch 41: head: default, loss=0.02592565, RMSE_E_per_atom=    6.08 meV, RMSE_F=   36.00 meV / A
# 2025-01-08 06:37:40.848 INFO: Epoch 42: head: default, loss=0.02741782, RMSE_E_per_atom=    4.91 meV, RMSE_F=   37.02 meV / A
# 2025-01-08 06:37:42.372 INFO: Epoch 43: head: default, loss=0.03051599, RMSE_E_per_atom=   30.62 meV, RMSE_F=   38.94 meV / A
# 2025-01-08 06:37:43.887 INFO: Epoch 44: head: default, loss=0.03282633, RMSE_E_per_atom=   11.63 meV, RMSE_F=   40.50 meV / A
# 2025-01-08 06:37:45.440 INFO: Epoch 45: head: default, loss=0.03354027, RMSE_E_per_atom=    1.59 meV, RMSE_F=   40.95 meV / A
# 2025-01-08 06:37:47.062 INFO: Epoch 46: head: default, loss=0.02639592, RMSE_E_per_atom=    2.00 meV, RMSE_F=   36.33 meV / A
# 2025-01-08 06:37:48.687 INFO: Epoch 47: head: default, loss=0.03412414, RMSE_E_per_atom=    4.74 meV, RMSE_F=   41.30 meV / A
# 2025-01-08 06:37:50.199 INFO: Epoch 48: head: default, loss=0.02392026, RMSE_E_per_atom=   14.10 meV, RMSE_F=   34.55 meV / A
# 2025-01-08 06:37:51.758 INFO: Epoch 49: head: default, loss=0.02440712, RMSE_E_per_atom=    1.32 meV, RMSE_F=   34.93 meV / A
# 2025-01-08 06:37:51.758 INFO: Training complete
# 2025-01-08 06:37:51.758 INFO:
# 2025-01-08 06:37:51.758 INFO: ===========RESULTS===========
# 2025-01-08 06:37:51.758 INFO: Computing metrics for training, validation, and test sets
# 2025-01-08 06:37:51.759 INFO: Loading checkpoint: /content/mace/results/si_run-123_epoch-48.pt
# /usr/local/lib/python3.10/dist-packages/mace/tools/checkpoint.py:187: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   torch.load(f=checkpoint_info.path, map_location=device),
# 2025-01-08 06:37:51.794 INFO: Loaded Stage one model from epoch 48 for evaluation
# 2025-01-08 06:37:51.795 INFO: Evaluating train_default ...
# 2025-01-08 06:37:53.627 INFO: Evaluating valid_default ...
# 2025-01-08 06:37:53.686 INFO: Error-table on TRAIN and VALID:
# +---------------+---------------------+------------------+-------------------+
# |  config_type  | RMSE E / meV / atom | RMSE F / meV / A | relative F RMSE % |
# +---------------+---------------------+------------------+-------------------+
# | train_default |           14.4      |         37.4     |          4.08     |
# | valid_default |           14.1      |         34.6     |          3.77     |
# +---------------+---------------------+------------------+-------------------+
# 2025-01-08 06:37:53.686 INFO: Saving model to /content/mace/results/si_run-123.model
# 2025-01-08 06:37:53.894 INFO: Compiling model, saving metadata to /content/mace/results/si_compiled.model
# 2025-01-08 06:37:54.795 INFO: Done
# CPU times: user 724 ms, sys: 77.5 ms, total: 802 ms
# Wall time: 1min 48s

# %% [markdown]
# **Extra:** Try running the model with different hyperparameters. We didn't mention any hyperparameters for the radial network unlike NequIP. Can you find out what are the radial network hyperparameters in MACE?
#
# *Hint: Execute* `!python3 ./mace/scripts/run_train.py -h` *for more information.*

# %%
# Check the output files
mace_train_dir = Path(parameters_mace["model_dir"])
for file in mace_train_dir.rglob("*"):
    print(file)
# Out:
# /content/mace/results/si_run-123_epoch-48.pt
# /content/mace/results/si.model
# /content/mace/results/si_compiled.model
# /content/mace/results/si_run-123.log
# /content/mace/results/si_run-123_debug.log
# /content/mace/results/si_run-123_train.txt
# /content/mace/results/si_run-123.model

# %% [markdown]
# Check the file saved as `..._train.txt` for information of about training.

# %%
mace_train_txt = mace_train_dir / f"{parameters_mace['name']}_run-{parameters_mace['seed']}_train.txt"

# Parsing the file
eval_data = {}
opt_data = {}

with open(mace_train_txt, 'r') as file:
    lines = file.readlines()

    for line in lines:
        try:
            record = json.loads(line)

            if record["mode"] == "eval":
                # Extract the epoch
                epoch = record.get("epoch", None)
                epoch_key = epoch if epoch is not None else None

                # Initialize a sub-dictionary for this epoch if not already present
                if epoch_key not in eval_data:
                    eval_data[epoch_key] = {}

                # Add all other keys (except 'mode' and 'epoch') to the sub-dictionary
                for key, value in record.items():
                    if key not in ["mode", "epoch"]:
                        eval_data[epoch_key][key] = value

            elif record["mode"] == "opt":
                # Extract the epoch
                epoch = record.get("epoch", None)
                epoch_key = epoch if epoch is not None else None

                # Initialize a sub-dictionary for this epoch if not already present
                if epoch_key not in opt_data:
                    opt_data[epoch_key] = {}

                # Initialize lists for all keys including 'epoch' if not present
                for key in record:
                    if key not in ["mode", "epoch"]: # Removed "epoch" to initialize it
                        if key not in opt_data[epoch_key]:  # This line is crucial
                            opt_data[epoch_key][key] = []

                # Append values to the lists
                for key, value in record.items():
                    if key not in ["mode", "epoch"]:
                        opt_data[epoch_key][key].append(value)

        except json.JSONDecodeError:
            continue

# %%
opt_data[0]
# Out:
# {'loss': [90.7524642944336,
#   66.86540985107422,
#   63.53081512451172,
#   54.7272834777832,
#   34.14562225341797,
#   16.607059478759766,
#   9.647543907165527,
#   20.342971801757812,
#   33.9659309387207],
#  'time': [0.7719368934631348,
#   2.088665723800659,
#   5.7991111278533936,
#   3.1928374767303467,
#   2.536198377609253,
#   0.18815875053405762,
#   0.15572690963745117,
#   0.1545853614807129,
#   0.15537738800048828]}

# %%
eval_data[0]
# Out:
# {'loss': 6.789792537689209,
#  'mae_e': 67.0640640258789,
#  'mae_e_per_atom': 1.047876000404358,
#  'rmse_e': 67.06483459472656,
#  'rmse_e_per_atom': 1.0478880405426025,
#  'q95_e': 67.43828125,
#  'mae_f': 0.45980212092399597,
#  'rel_mae_f': 63.041198158952405,
#  'rmse_f': 0.5731569528579712,
#  'rel_rmse_f': 62.545618954296685,
#  'q95_f': 1.134639322757721,
#  'time': 0.056252479553222656}

# %% [markdown]
# The `..._train.txt` file contains two types of data:
#
# 1. Optimization Data: Batch Optimization data
# 2. Evaluation Data: Validation data

# %%
train_loss_data = []
valid_loss_data = []

for epoch in opt_data.keys():
  train_loss_data.append(opt_data[epoch]['loss'])
  valid_loss_data.append(eval_data[epoch]['loss'])

average_train_loss_data=[]

num_validation_configs = parameters_mace['valid_fraction'] * num_configs
num_train_configs = num_configs - num_validation_configs

for loss in train_loss_data:
  average_train_loss_data.append(np.sum(loss) / num_train_configs)

plt.figure(figsize=(10, 6))
plt.plot(valid_loss_data, label='validation_loss')
plt.plot(average_train_loss_data, label='training_loss')
plt.xlabel('Epoch')
plt.ylabel('Metric Value')
plt.title('MACE Training')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3.5. Molecular Dynamics using MACE <a name="mace-md"></a>

# %% [markdown]
# #### 3.5.1 MACE Calculator
# MACE models can run molecular dynamics or geometry optimisation through the ASE calculator. There is no need for model deployement unlike in NequIP.

# %%
init_conf = read(test_data, index=0)
init_conf
# Out:
# Atoms(symbols='Si64', pbc=True, cell=[10.861999859992501, 10.861999859992501, 10.861999859992501], calculator=SinglePointCalculator(...))

# %%
from mace.calculators import MACECalculator

# Specify the path to the pre-trained MACE model
mace_model = mace_train_dir / f"{parameters_mace['name']}_compiled.model"

# Initialize the MACE calculator with the specified model
mace_calc = MACECalculator(model_paths=[mace_model], device=device, default_dtype="float32")

# Call the simpleMD function to perform a molecular dynamics simulation
simpleMD(init_conf, temp=800, calc=mace_calc, fname= 'mace/results/mace_md_si_800K.xyz', s=10, T=500)
# Out:
# MD finished in 0.85 minutes!

# %% [markdown]
# ### 3.6. MACE Foundational Models <a name="mace-foundational"></a>
#
# These are a single general-purpose ML model, pre-trained on a public database of 150k inorganic crystals, that is capable of running stable molecular dynamics on molecules and materials. We will be using one such model called [**MACE-MP: Materials Project Force Fields**](https://arxiv.org/abs/2401.00096) to demonstrate the power and generalizability of MACE.

# %%
init_conf = read(test_data, index=0)
init_conf
# Out:
# Atoms(symbols='Si64', pbc=True, cell=[10.861999859992501, 10.861999859992501, 10.861999859992501], calculator=SinglePointCalculator(...))

# %%
from mace.calculators import mace_mp

# Initialize the MACE-MP calculator
mace_mp_calc = mace_mp(device=device, default_dtype="float32")

# Call the simpleMD function to perform a molecular dynamics simulation
simpleMD(init_conf, temp=800, calc=mace_mp_calc, fname ='mace/results/mace_mp_md_si_800K.xyz', s=10, T=500)
# Out:
# MD finished in 0.87 minutes!

# %%
parameters_nequip["dataset_file_name"] = "BOTNet-datasets/dataset_3BPA/train_300K.xyz"
parameters_nequip["chemical_symbols"] = ['C','H','O','N']
parameters_nequip["run_name"] = "botnet_1"

# %% [markdown]
# ## 4. Exercises <a name="exercises"></a>

# %% [markdown]
# ### 4.1. Evaluating NequIP and MACE <a name="ex-evaluate"></a>
#
# We haven't tested the trained NequIP or MACE model. To test it we can use:
#
#   - Use `nequip-evaluate` for NequIP model. [Refer this](https://github.com/mir-group/nequip?tab=readme-ov-file#evaluating-trained-models-and-their-error) or use `nequip-evaluate --help` for more help.
#     - Ensure you change the `dataset_file_name` to the test file.
#   - Use `eval_configs.py` for MACE model. [Refer this](https://mace-docs.readthedocs.io/en/latest/guide/evaluation.html) or use `!python3 mace/scripts/eval_configs.py -h` for more help.
#
# Which model performs better?

# %% [markdown]
# ### 4.2. Play with the hyperparamters for NequIP and MACE. <a name="ex-hyperparam"></a>
#
# You tested the models in the previous exercise. But was the comparison fair?
#
# How are they similar (look at the meaning of the hyperparamaters)? Can we get NequIP model by tweaking parameters of MACE?
#
# *Hint:* *Look at the* `correlation` *hyperparameter*.

# %% [markdown]
# ### 4.3. Training complex datasets <a name="ex-botnet"></a>
#
# Download the BOTNET dataset:
#
# ```
# !git clone https://github.com/davkovacs/BOTNet-datasets.git
# ```
#
# The [BOTNET](https://github.com/davkovacs/BOTNet-datasets) collection of dataset used in the paper by [Batatia et.al](https://arxiv.org/abs/2205.06643). The collection contains the following datasets:
#
# 1. **Ethanol and Methanol:** Consists of two training datasets, first taken revMD17 dataset and was sampled from a long 500 K Ab Initio molecular dynamics trajectory and the second training set contains the 1000 ethanol geometries of the first training set but is augmented by 300 K methanol geometries also sampled from 500 K Ab Initio molecular dynamics simulation.
# 2. **3BPA:** Dataset contains snapshots of a large flexible drug-like organic molecule sampled from different temperature molecular dynamics trajectories.
# 3. **Acetylacetone:** Dataset contains data related to acetylacetone (acac), specifically focusing on proton transfer reactions between its tautomeric forms. This dataset includes configurations obtained from Ab Initio molecular dynamics simulations at 300 K.
#
# Look at **[3BPA dataset](https://github.com/davkovacs/BOTNet-datasets/tree/main/dataset_ethanol)**. Train on the `train_300K.xyz` dataset. What will the parameters will you change? Don't focus on hyperparameters for now.
#
# Evaluate and run the MD simulations on the `test_300K.xyz` file. Is the run stable? Now change the hyperparameters to make the model more complicated (increase the features, epoch, and layers). Observe the improvements.

# %% [markdown]
# ## 5. BONUS: Visualizing `.xyz` files <a name="ovito"></a>
#
# We can visualize the Molecular Dynamics file using softwares such as [OVITO](https://www.ovito.org/).
#
# 1. This can be done by downloading and installing OVITO software on your local device from the following website - [Download OVITO](https://www.ovito.org/#download)
#
# 2. After downloading it, open the application. [Refer this for usage instructions](https://www.ovito.org/manual).
#
# 3. Download `.xyz` trajectory files to your local device.
#
# ```
# from google.colab import files
# files.download(<filepath>)
# ```
#
#
#
# 4. Go to `Files`->`Load File...`-> Load the Trajectory File.
#
# 5. Play the animation.

# %%
# Downloading files from colab to local devices
from google.colab import files

files.download(nequip_results_dir /'nequip_md_si_800K.xyz')
files.download(mace_results_dir / 'mace_md_si_800K.xyz')
files.download(mace_results_dir /'mace_mp_md_si_800K.xyz')
